# %% [markdown]
# # Yucatan Peninsula Hurricanes

# %% [markdown]
# ## 1. Archive exploration
# brief description:

# %% [markdown]
# ## 2. Data loading and preliminary exploration

# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in data
df = pd.read_csv('data/hf071-01-hurricanes.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   code        105 non-null    object
#  1   start.date  105 non-null    object
#  2   end.date    105 non-null    object
#  3   number      105 non-null    int64
#  4   name        33 non-null     object
#  5   ss          105 non-null    int64
#  6   track       105 non-null    object
#  7   rf.max      105 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.7+ KB

# %% [markdown]
# ## 3. Brainstorm
# How many hurricanes with Saffir-Simpson category 5 have been registered and what was their duration?
#
# 1. Filter for category 5 data (get dimensions)
# 2. Convert start.date and end.date to datetime
# 3. Create a new column "duration"

# %% [markdown]
# ## 4. Data wrangling

# %%
# 1. Filter for category 5 data (get dimensions)
df_cat5 = df[df['ss']==5]
df_cat5.shape
# Out:
# (4, 8)

# %%
# 2. Convert start.date and end.date to datetime
df_cat5.loc[:,'start.date'] = pd.to_datetime(df_cat5['start.date'])
df_cat5.loc[:, 'end.date'] = pd.to_datetime(df_cat5['end.date'])

# Make sure the datatype is now as datetime
df_cat5.dtypes
# Out:
# code          object
# start.date    object
# end.date      object
# number         int64
# name          object
# ss             int64
# track         object
# rf.max        object
# dtype: object

# %%
# 3. Create a new column "duration" 
df_cat5.loc[:, 'duration'] = df_cat5['end.date'] - df_cat5['start.date']

# %%
# Look at the complete data frame
df_cat5.head()
# Out:
#        code           start.date             end.date  number     name  ss  \
# 76   Y1955b  1955-09-28 00:00:00  1955-09-28 00:00:00      10    Janet   5
# 96   Y1980a  1980-08-07 00:00:00  1980-08-08 00:00:00       1    Allen   5
# 98    Y1988  1988-09-14 00:00:00  1988-09-15 00:00:00       8  Gilbert   5
# 103   Y1998  1998-10-27 00:00:00  1998-10-28 00:00:00      13    Mitch   5
#
#     track rf.max         duration
# 76      N     F3  0 days 00:00:00
# 96      O     F3  1 days 00:00:00
# 98      N     F3  1 days 00:00:00
# 103     S     F1  1 days 00:00:00

# %% [markdown]
# ## 5: Visualize Saffir-Simpson categories across time
# a. Create a scatter plot of the start date of the hurricanes against the Saffir-Simpson scale. Use matplotlib to customize your graph, including updating the tick labels to be only 1, 2, 3, 4, and 5 since the Saffir-Simpsn scale does not take decimal values.
#
# b. Analyze your plot and write (in full sentences!) any trends that you observe.

# %%
#  Convert start.date and end.date to datetime
df.loc[:,'start.date'] = pd.to_datetime(df['start.date'])
df.loc[:, 'end.date'] = pd.to_datetime(df['end.date'])

# %%
# Create scatter plot of 
plt.scatter('start.date', 'ss', data = df, marker = '.', color = 'hotpink')
plt.yticks([1, 2, 3, 4, 5])
plt.xlabel('Year')
plt.ylabel('Safir-Simpson Scale')
plt.title('Yucatan Peninsula Hurricanes based on the Saffir-Simpson Scale(1851-2000)')
plt.show()

# %% [markdown]
# # Analysis
# Category 4 and 5 hurricanes have only been occuring since approximately 1950. These hurricanes correlate with when we know that effects of climate change were begginning. Category 5 hurricanes are also more common in from 1980 to 2000.

# %%
# Import necessary packages
import pandas as pd
import matplotlib.pyplot as plt

# Read in data
df = pd.read_csv('data/hf071-01-hurricanes.csv')

# 1. Filter for category 5 data (get dimensions)
df_cat5 = df[df['ss']==5]

# 2. Convert start.date and end.date to datetime
df_cat5.loc[:,'start.date'] = pd.to_datetime(df_cat5['start.date'])
df_cat5.loc[:, 'end.date'] = pd.to_datetime(df_cat5['end.date'])

# 3. Create a new column "duration" 
df_cat5.loc[:, 'duration'] = df_cat5['end.date'] - df_cat5['start.date'] 

#  Convert start.date and end.date to datetime
df.loc[:,'start.date'] = pd.to_datetime(df['start.date'])
df.loc[:, 'end.date'] = pd.to_datetime(df['end.date'])

# Create scatter plot of 
plt.scatter('start.date', 'ss', data = df, marker = '.', color = 'hotpink')
plt.yticks([1, 2, 3, 4, 5])
plt.xlabel('Year')
plt.ylabel('Safir-Simpson Scale')
plt.title('Yucatan Peninsula Hurricanes based on the Saffir-Simpson Scale(1851-2000)')
plt.show()
# Out:
# /tmp/ipykernel_3296329/240962551.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat5.loc[:, 'duration'] = df_cat5['end.date'] - df_cat5['start.date']
